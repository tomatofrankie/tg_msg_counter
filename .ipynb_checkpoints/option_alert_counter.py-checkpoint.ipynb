# %%
# DON'T RUN THIS BLOCK AGAIN

import configparser
import json
from datetime import datetime
from telethon import TelegramClient
from telethon.errors import SessionPasswordNeededError

# Reading Configs
config = configparser.ConfigParser()
config.read("config.ini")

# Setting configuration values
api_id = config['Telegram']['api_id']
api_hash = config['Telegram']['api_hash']

api_hash = str(api_hash)

phone = config['Telegram']['phone']
username = config['Telegram']['username']

# Create the client and connect
client = TelegramClient(username, api_id, api_hash)
await client.start()
print("Client Created")
# Out:
# Client Created

# %%
# DON'T RUN THIS BLOCK AGAIN

# Ensure you're authorized
if not client.is_user_authorized():
    client.send_code_request(phone)
    try:
        client.sign_in(phone, input('Enter the code: '))
    except SessionPasswordNeededError:
        client.sign_in(password=input('Password: '))

from telethon.tl.types import PeerChannel

# user_input_channel = input("enter entity(telegram URL or entity id):")
user_input_channel = '1001546061018'

if user_input_channel.isdigit():
    entity = PeerChannel(-int(user_input_channel))
else:
    entity = user_input_channel

await client.connect()
my_channel = await client.get_entity(entity)
# Out:
# /var/folders/ym/67x0srsx2ln9vy4qtlvtdv500000gn/T/ipykernel_47279/2990546721.py:4: RuntimeWarning: coroutine 'UserMethods.is_user_authorized' was never awaited
#   if not client.is_user_authorized():
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
# Getting Channel messages
from telethon.tl.functions.messages import GetHistoryRequest
offset_id = 0
limit = 100
all_messages = []
total_messages = 0
total_count_limit = 300
a_long_call = 0
a_otm_call = 0
a_long_put = 0
a_otm_put = 0
a_short_call = 0
a_short_put = 0
b_long_call = 0
b_otm_call = 0
b_long_put = 0
b_otm_put = 0
b_short_call = 0
b_short_put = 0
iteration = 1
due_a_object = 0
due_b_object = 0
due_a = '2022-07-22'
due_b = '2022-07-29'

while True:
#     print("Current Offset ID is:", offset_id, "; Total Messages:", total_messages)
    history = await client(GetHistoryRequest(
        peer=my_channel,
        offset_id=offset_id,
        offset_date=datetime.now(),
        add_offset=0,
        limit=limit,
        max_id=0,
        min_id=0,
        hash=0
    ))
    if not history.messages:
        break
    messages = history.messages
    for message in messages:
        all_messages.append(message.to_dict())
    offset_id = messages[len(messages) - 1].id
    total_messages = len(all_messages)
    if total_count_limit != 0 and total_messages >= total_count_limit:
        break
# print("Total Messages:", total_messages)

date_now = datetime(2022, 7, 22)
date = date_now.strftime('%Y-%m-%d')


for item in all_messages:
    content = item['message']
    
    due_index = content.index('到期日:') + 5
#     if iteration == 1:
# #         due_a = content[due_index:due_index + 10]
#         due_a = '2022-07-22'
#     if iteration >= 1 and due_a < content[due_index:due_index + 10]:
# #         due_b = content[due_index:due_index + 10]
#         due_b = '2022-07-29'
#         due_b_object = datetime.fromisoformat(due_b)
    iteration += 1
    
    buy_index = content.index('成交日期') + 5
    buy_date = content[buy_index:buy_index + 10]
    datetime_object = datetime.fromisoformat(buy_date)
    
    due_date = content[due_index:due_index + 10]
    due_date = datetime.fromisoformat(due_date)
    
    strike_index = content.index('行權價') + 5
    strike = float(content[strike_index:strike_index + 5])
    price_index = content.index('正股股價') + 6
    price = float(content[price_index:price_index + 5])
    
    
    if datetime_object >= date_now:
        due_b_object = datetime.fromisoformat(due_b)
        if due_b_object != due_date:
            if 'LONG CALL' in content:
                a_long_call += 1
                if price < strike:
                    a_otm_call += 1
            if 'LONG PUT' in content:
                a_long_put += 1
                if price > strike:
                    a_otm_put += 1
            if 'SHORT CALL' in content:
                a_short_call += 1
            if 'SHORT PUT' in content:
                a_short_put += 1
                
        if due_b_object == due_date:
            if 'LONG CALL' in content:
                b_long_call += 1
                if price < strike:
                    b_otm_call += 1
            if 'LONG PUT' in content:
                b_long_put += 1
                if price > strike:
                    b_otm_put += 1
            if 'SHORT CALL' in content:
                b_short_call += 1
            if 'SHORT PUT' in content:
                b_short_put += 1
                
                
print('Option alert of', date,':')
print('\n\033[1mDue',due_a,':\033[0m')
print('Number of LONG CALL:', a_long_call)
print('Number of LONG PUT:', a_long_put)
print('Number of SHORT CALL:', a_short_call)
print('Number of SHORT PUT:', a_short_put)
# print('Net CALL:', a_long_call - a_short_call)
# print('Net PUT:', a_long_put - a_short_put)
print('Number of OTM LONG CALL:', a_otm_call)
print('Number of OTM LONG PUT:', a_otm_put)
# print('Total number of alerts:', a_long_call + a_long_put + a_short_call + a_short_put)
print('\n\033[1mDue',due_b,':\033[0m')
print('Number of LONG CALL:', b_long_call)
print('Number of LONG PUT:', b_long_put)
print('Number of SHORT CALL:', b_short_call)
print('Number of SHORT PUT:', b_short_put)
# print('Net CALL:', b_long_call - b_short_call)
# print('Net PUT:', b_long_put - b_short_put)
print('Number of OTM LONG CALL:', b_otm_call)
print('Number of OTM LONG PUT:', b_otm_put)
# print('Total number of alerts:', b_long_call + b_long_put + b_short_call + b_short_put)
# Out:
# Option alert of 2022-07-22 :
#
# Due 2022-07-22 :
# Number of LONG CALL: 30
# Number of LONG PUT: 36
# Number of SHORT CALL: 31
# Number of SHORT PUT: 38
# Number of OTM LONG CALL: 13
# Number of OTM LONG PUT: 10
#
# Due 2022-07-29 :
# Number of LONG CALL: 39
# Number of LONG PUT: 34
# Number of SHORT CALL: 39
# Number of SHORT PUT: 17
# Number of OTM LONG CALL: 29
# Number of OTM LONG PUT: 21
# Task exception was never retrieved
# future: <Task finished name='Task-23145' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23146' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Unhandled error while processing msgs
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 540, in _recv_loop
#     await self._process_message(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 634, in _handle_container
#     await self._process_message(inner_message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 645, in _handle_gzip_packed
#     await self._process_message(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 656, in _handle_update
#     self._update_callback(message.obj)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 304, in _handle_update
#     self.session.process_entities(update)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23149' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23154' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23155' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23153' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23152' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Unhandled error while processing msgs
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 540, in _recv_loop
#     await self._process_message(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 634, in _handle_container
#     await self._process_message(inner_message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 645, in _handle_gzip_packed
#     await self._process_message(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 656, in _handle_update
#     self._update_callback(message.obj)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 304, in _handle_update
#     self.session.process_entities(update)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Unhandled error while processing msgs
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 540, in _recv_loop
#     await self._process_message(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 634, in _handle_container
#     await self._process_message(inner_message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 645, in _handle_gzip_packed
#     await self._process_message(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 656, in _handle_update
#     self._update_callback(message.obj)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 304, in _handle_update
#     self.session.process_entities(update)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23157' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23160' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23159' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Unhandled error while processing msgs
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 540, in _recv_loop
#     await self._process_message(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 634, in _handle_container
#     await self._process_message(inner_message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 645, in _handle_gzip_packed
#     await self._process_message(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 656, in _handle_update
#     self._update_callback(message.obj)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 304, in _handle_update
#     self.session.process_entities(update)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23162' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23164' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Unhandled error while processing msgs
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 540, in _recv_loop
#     await self._process_message(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 634, in _handle_container
#     await self._process_message(inner_message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 645, in _handle_gzip_packed
#     await self._process_message(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 656, in _handle_update
#     self._update_callback(message.obj)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 304, in _handle_update
#     self.session.process_entities(update)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23176' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23173' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Unhandled error while processing msgs
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 540, in _recv_loop
#     await self._process_message(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 634, in _handle_container
#     await self._process_message(inner_message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 645, in _handle_gzip_packed
#     await self._process_message(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 656, in _handle_update
#     self._update_callback(message.obj)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 304, in _handle_update
#     self.session.process_entities(update)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Unhandled error while processing msgs
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 540, in _recv_loop
#     await self._process_message(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 634, in _handle_container
#     await self._process_message(inner_message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 645, in _handle_gzip_packed
#     await self._process_message(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 555, in _process_message
#     await handler(message)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/network/mtprotosender.py", line 656, in _handle_update
#     self._update_callback(message.obj)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 304, in _handle_update
#     self.session.process_entities(update)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23178' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23195' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23194' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23180' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23196' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23189' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23193' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23205' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 460, in get_input_entity
#     channels = await self(functions.channels.GetChannelsRequest([
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23199' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23198' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23201' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23200' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23202' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23204' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23203' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# ...
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23555' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23560' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23564' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23563' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23566' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23550' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23562' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23565' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23559' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23561' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23568' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 460, in get_input_entity
#     channels = await self(functions.channels.GetChannelsRequest([
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-23569' coro=<UpdateMethods._dispatch_update() done, defined at /Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py:399> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 408, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/updates.py", line 558, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/client/users.py", line 85, in _call
#     self.session.process_entities(result)
#   File "/Users/frankie/opt/anaconda3/lib/python3.9/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database

# %%
# Find correlation between option alert and change in the next day
